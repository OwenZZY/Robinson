# %%
import Bounds as bds
import Bound as bd
import Table as tbl
import UpperBounds as ubds
import LowerBounds as lbds
import Robinson as Rob
import numpy as np

# %%
# %load_ext autoreload
# %autoreload 2

# %%
a = bd.Bound(ds = [1,2,3])
print(a)
b = bd.Bound(None,toCpy=a)
print("b: ", b)
d = a+b

c = (a+b).cpy()
print(a,c)

print(a <= c)
print(a >= c)
# Out:
# [1 2 3]
# b:  [1 2 3]
# [1 2 3] [2 4 6]
# True
# False

# %%
a3 = bd.Bound(ds= [2,4])
a2 = bd.Bound(ds= [3,2])
a1 = bd.Bound(ds =[2,2])
A_ = bds.Bounds()

A = lbds.LowerBounds(A_)
A.union(a1)
A.union(a2)
print(A)
B = lbds.LowerBounds(toCpy=A)
B.union(a3)
print(B)
#C = A.oMinusU(B)
#D = A.oPlusU(B)
#print(C, D)
# Out:
# {[3 2]}
# {[3 2],[2 4]}

# %%
a1 = bd.Bound(ds= [2,4])
a2 = bd.Bound(ds= [3,2])
a3 = bd.Bound(ds =[2,2])
A = lbds.LowerBounds()
A.union(a1)
A.union(a2)
print(A)
B = ubds.UpperBounds()
B.union(a3)
print(B)
C = A - (B)
D = A + (B)
print(C, D)
# Out:
# {[2 4],[3 2]}
# {[2 2]}
# {[0 2],[1 0]} {[4 6],[5 4]}

# %%
T = [[A, B, C],
[None, B, C],
[None, None, C],
]

T = tbl.Table(withArray= T)

T.joinBoundsAt(0,0, D)
print(T)
len(T)
print(T.TypeTable())
# T + T
# Out:
# (0,0): {[4 6],[5 4]}	(0,1): {[2 2]}	(0,2): {[0 2],[1 0]}
# (1,0): {[2 2]}	(1,1): {[2 2]}	(1,2): {[0 2],[1 0]}
# (2,0): {[0 2],[1 0]}	(2,1): {[0 2],[1 0]}	(2,2): {[0 2],[1 0]}
#
# LowerBounds	UpperBounds	LowerBounds
# UpperBounds	UpperBounds	LowerBounds
# LowerBounds	LowerBounds	LowerBounds

# %%
a = np.array([12,3,4])
print(a)
b = np.array(a)
print(b+1)
len(b)
# Out:
# [12  3  4]
# [13  4  5]
# 3

# %%
class Test:
  def __init__(self):
    self.n = 3
  def __len__(self):
    return 7
  def dim(self):
    return 12

# %%
T = []
if not isinstance(T, list):
    
    raise Exception("withArray variable expects list, "+str(type(T))+" given.")

# %%
G = [ [ 2, 2, 1, 0, 0, 0 ],
      [ 2, 2, 2, 1, 1, 1 ],
      [ 1, 2, 2, 2, 1, 1 ],
      [ 0, 1, 2, 2, 2, 1 ],
      [ 0, 1, 1, 2, 2, 2 ],
      [ 0, 1, 1, 1, 2, 2 ] ]
R = Rob.Robinson(G,  k = 2)
R.find_embedding()
# Out:
# Within table
#  (0,0): {}	(0,1): {[0 1]}	(0,2): {[1 0],[0 2]}	(0,3): {[1 0]}	(0,4): {[1 1]}	(0,5): {[1 1]}
# (1,0): {[0 1]}	(1,1): {}	(1,2): {[0 1],[ 1 -1]}	(1,3): {[0 2],[ 1 -1]}	(1,4): {[1 0]}	(1,5): {[1 0]}
# (2,0): {[1 0],[0 2]}	(2,1): {[0 1],[ 1 -1]}	(2,2): {}	(2,3): {[0 1],[ 1 -1]}	(2,4): {[1 0],[0 2]}	(2,5): {[1 0]}
# (3,0): {[1 0]}	(3,1): {[0 2],[ 1 -1]}	(3,2): {[0 1],[ 1 -1]}	(3,3): {}	(3,4): {[0 1],[ 1 -1]}	(3,5): {[0 1],[ 1 -1]}
# (4,0): {[1 1]}	(4,1): {[1 0]}	(4,2): {[1 0],[0 2]}	(4,3): {[0 1],[ 1 -1]}	(4,4): {}	(4,5): {[0 1],[ 1 -1]}
# (5,0): {[1 1]}	(5,1): {[1 0]}	(5,2): {[1 0]}	(5,3): {[0 1],[ 1 -1]}	(5,4): {[0 1],[ 1 -1]}	(5,5): {}
#
# Away table
#  (0,0): {}	(0,1): {[0 1]}	(0,2): {[0 1],[ 1 -1]}	(0,3): {[1 0]}	(0,4): {[1 0],[0 2]}	(0,5): {[1 1]}
# (1,0): {[0 1]}	(1,1): {}	(1,2): {[0 0],[-1  2]}	(1,3): {[0 1],[ 1 -1]}	(1,4): {[0 1],[ 1 -1]}	(1,5): {[0 2],[1 0]}
# (2,0): {[0 1],[ 1 -1]}	(2,1): {[0 0],[-1  2]}	(2,2): {}	(2,3): {[0 0]}	(2,4): {[0 1]}	(2,5): {[0 1]}
# (3,0): {[1 0]}	(3,1): {[0 1],[ 1 -1]}	(3,2): {[0 0]}	(3,3): {}	(3,4): {[0 0]}	(3,5): {[0 1]}
# (4,0): {[1 0],[0 2]}	(4,1): {[0 1],[ 1 -1]}	(4,2): {[0 1]}	(4,3): {[0 0]}	(4,4): {}	(4,5): {[0 0],[-1  2]}
# (5,0): {[1 1]}	(5,1): {[0 2],[1 0]}	(5,2): {[0 1]}	(5,3): {[0 1]}	(5,4): {[0 0],[-1  2]}	(5,5): {}
#
# {[0 1]}  versus  {[0 1]}
# -------iter ends-----
# (0, 1)

# %%
G = [ [ 2, 2, 1, 0, 0 ],
      [ 2, 2, 2, 1, 1 ],
      [ 1, 2, 2, 2, 1 ],
      [ 0, 1, 2, 2, 2 ],
      [ 0, 1, 1, 2, 2 ] ]
R = Rob.Robinson(G,  k = 2)
R.find_embedding()
# Out:
# Within table
#  (0,0): {}	(0,1): {[0 1]}	(0,2): {[1 0],[0 2]}	(0,3): {[1 1]}	(0,4): {[1 1]}
# (1,0): {[0 1]}	(1,1): {}	(1,2): {[0 1],[ 1 -1]}	(1,3): {[1 0],[0 2]}	(1,4): {[1 0]}
# (2,0): {[1 0],[0 2]}	(2,1): {[0 1],[ 1 -1]}	(2,2): {}	(2,3): {[0 1]}	(2,4): {[1 0],[0 2]}
# (3,0): {[1 1]}	(3,1): {[1 0],[0 2]}	(3,2): {[0 1]}	(3,3): {}	(3,4): {[0 1],[ 1 -1]}
# (4,0): {[1 1]}	(4,1): {[1 0]}	(4,2): {[1 0],[0 2]}	(4,3): {[0 1],[ 1 -1]}	(4,4): {}
#
# Away table
#  (0,0): {}	(0,1): {[0 0],[-1  2]}	(0,2): {[0 1],[ 1 -1]}	(0,3): {[1 0]}	(0,4): {[1 0],[0 2]}
# (1,0): {[0 0],[-1  2]}	(1,1): {}	(1,2): {[0 0]}	(1,3): {[0 1],[ 1 -1]}	(1,4): {[0 1],[ 1 -1]}
# (2,0): {[0 1],[ 1 -1]}	(2,1): {[0 0]}	(2,2): {}	(2,3): {[0 0]}	(2,4): {[0 1]}
# (3,0): {[1 0]}	(3,1): {[0 1],[ 1 -1]}	(3,2): {[0 0]}	(3,3): {}	(3,4): {[0 0]}
# (4,0): {[1 0],[0 2]}	(4,1): {[0 1],[ 1 -1]}	(4,2): {[0 1]}	(4,3): {[0 0]}	(4,4): {}
#
# -------iter  1  ends-----
# Within table
#  (0,0): {}		(0,1): {[0 1],[-1  4]}	(0,2): {[1 0],[0 2]}	(0,3): {[1 1],[0 3]}	(0,4): {[1 1],[0 4]}
# (1,0): {[0 1],[-1  4]}	(1,1): {}		(1,2): {[0 1],[ 1 -1]}	(1,3): {[1 0],[0 2]}	(1,4): {[1 0],[0 3]}
# (2,0): {[1 0],[0 2]}	(2,1): {[0 1],[ 1 -1]}	(2,2): {}		(2,3): {[0 1],[-1  4]}	(2,4): {[1 0],[0 2],[-1  5]}
# (3,0): {[1 1],[0 3]}	(3,1): {[1 0],[0 2]}	(3,2): {[0 1],[-1  4]}	(3,3): {}		(3,4): {[0 1],[ 1 -1],[-1  4]}
# (4,0): {[1 1],[0 4]}	(4,1): {[1 0],[0 3]}	(4,2): {[1 0],[0 2],[-1  5]}	(4,3): {[0 1],[ 1 -1],[-1  4]}	(4,4): {}
#
# Away table
#  (0,0): {}		(0,1): {[0 0],[-1  2],[ 1 -2]}	(0,2): {[0 1],[ 1 -1]}	(0,3): {[1 0],[-1  3]}	(0,4): {[1 0],[0 2]}
# (1,0): {[0 0],[-1  2],[ 1 -2]}	(1,1): {}		(1,2): {[0 0],[ 1 -2]}	(1,3): {[0 1],[ 1 -1]}	(1,4): {[0 1],[ 1 -1]}
# (2,0): {[0 1],[ 1 -1]}	(2,1): {[0 0],[ 1 -2]}	(2,2): {}		(2,3): {[0 0],[ 1 -2],[-1  2]}	(2,4): {[0 1],[ 1 -2]}
# (3,0): {[1 0],[-1  3]}	(3,1): {[0 1],[ 1 -1]}	(3,2): {[0 0],[ 1 -2],[-1  2]}	(3,3): {}		(3,4): {[0 0],[ 1 -3]}
# (4,0): {[1 0],[0 2]}	(4,1): {[0 1],[ 1 -1]}	(4,2): {[0 1],[ 1 -2]}	(4,3): {[0 0],[ 1 -3]}	(4,4): {}
#
# -------iter  2  ends-----
# Within table
#  (0,0): {}		(0,1): {[0 1],[-1  4],[-2  7]}	(0,2): {[1 0],[0 2],[-1  5],[-2  8]}	(0,3): {[1 1],[0 3],[-1  6],[-2 10]}	(0,4): {[1 1],[0 4],[-1  7]}
# (1,0): {[0 1],[-1  4],[-2  7]}	(1,1): {}		(1,2): {[0 1],[ 1 -1],[-1  4],[-2  7]}	(1,3): {[1 0],[0 2],[-1  5],[-2  8]}	(1,4): {[1 0],[0 3],[-1  6],[-2  9]}
# (2,0): {[1 0],[0 2],[-1  5],[-2  8]}	(2,1): {[0 1],[ 1 -1],[-1  4],[-2  7]}	(2,2): {}		(2,3): {[0 1],[-1  4],[-2  7],[-3 11]}	(2,4): {[1 0],[0 2],[-1  5],[-2  8]}
# (3,0): {[1 1],[0 3],[-1  6],[-2 10]}	(3,1): {[1 0],[0 2],[-1  5],[-2  8]}	(3,2): {[0 1],[-1  4],[-2  7],[-3 11]}	(3,3): {}		(3,4): {[0 1],[ 1 -1],[-1  4],[-2  7],[-3 10]}
# (4,0): {[1 1],[0 4],[-1  7]}	(4,1): {[1 0],[0 3],[-1  6],[-2  9]}	(4,2): {[1 0],[0 2],[-1  5],[-2  8]}	(4,3): {[0 1],[ 1 -1],[-1  4],[-2  7],[-3 10]}	(4,4): {}
#
# Away table
#  (0,0): {}		(0,1): {[0 0],[-1  2],[ 1 -2],[ 2 -5]}	(0,2): {[0 1],[ 1 -1],[ 2 -4],[ 3 -7]}	(0,3): {[1 0],[-1  3],[ 2 -3],[ 3 -7]}	(0,4): {[1 0],[0 2],[ 2 -3]}
# (1,0): {[0 0],[-1  2],[ 1 -2],[ 2 -5]}	(1,1): {}		(1,2): {[0 0],[ 1 -2],[ 2 -5],[ 3 -8]}	(1,3): {[0 1],[ 1 -1],[ 2 -4],[ 3 -7]}	(1,4): {[0 1],[ 1 -1],[ 2 -4],[ 3 -7]}
# (2,0): {[0 1],[ 1 -1],[ 2 -4],[ 3 -7]}	(2,1): {[0 0],[ 1 -2],[ 2 -5],[ 3 -8]}	(2,2): {}		(2,3): {[0 0],[ 1 -2],[-1  2],[ 2 -5],[ 3 -9]}	(2,4): {[0 1],[ 1 -2],[ 2 -5]}
# (3,0): {[1 0],[-1  3],[ 2 -3],[ 3 -7]}	(3,1): {[0 1],[ 1 -1],[ 2 -4],[ 3 -7]}	(3,2): {[0 0],[ 1 -2],[-1  2],[ 2 -5],[ 3 -9]}	(3,3): {}		(3,4): {[0 0],[ 1 -3],[ 2 -6],[ 3 -9]}
# (4,0): {[1 0],[0 2],[ 2 -3]}	(4,1): {[0 1],[ 1 -1],[ 2 -4],[ 3 -7]}	(4,2): {[0 1],[ 1 -2],[ 2 -5]}	(4,3): {[0 0],[ 1 -3],[ 2 -6],[ 3 -9]}	(4,4): {}
#
# -------iter  3  ends-----
# Within table
#  (0,0): {}				(0,1): {[0 1],[-1  4],[-2  7],[-3 10],[-4 13],[-5 16],[-6 19],[-7 22],[-8 26]}	(0,2): {[1 0],[0 2],[-1  5],[-2  8],[-3 11],[-4 14],[-5 17],[-6 20],[-7 24],[-8 28]}	(0,3): {[1 1],[0 3],[-1  6],[-2  9],[-3 12],[-4 15],[-5 19],[-6 22],[-7 25],[-8 29]}	(0,4): {[1 1],[0 4],[-1  7],[-2 10],[-3 13],[-4 16],[-5 20]}
# (1,0): {[0 1],[-1  4],[-2  7],[-3 10],[-4 13],[-5 16],[-6 19],[-7 22],[-8 26]}	(1,1): {}				(1,2): {[0 1],[ 1 -1],[-1  4],[-2  7],[-3 10],[-4 13],[-5 16],[-6 19],[-7 23],[-8 27]}	(1,3): {[1 0],[0 2],[-1  5],[-2  8],[-3 11],[-4 14],[-5 17],[-6 20],[-7 24],[-8 27]}	(1,4): {[1 0],[0 3],[-1  6],[-2  9],[-3 12],[-4 15],[-5 18],[-6 21],[-7 25]}
# (2,0): {[1 0],[0 2],[-1  5],[-2  8],[-3 11],[-4 14],[-5 17],[-6 20],[-7 24],[-8 28]}	(2,1): {[0 1],[ 1 -1],[-1  4],[-2  7],[-3 10],[-4 13],[-5 16],[-6 19],[-7 23],[-8 27]}	(2,2): {}				(2,3): {[0 1],[-1  4],[-2  7],[-3 10],[-4 13],[-5 16],[-6 19],[-7 22],[-8 26],[-9 30]}	(2,4): {[1 0],[0 2],[-1  5],[-2  8],[-3 11],[-4 14],[-5 17],[-6 20],[-7 23],[-8 26]}
# (3,0): {[1 1],[0 3],[-1  6],[-2  9],[-3 12],[-4 15],[-5 19],[-6 22],[-7 25],[-8 29]}	(3,1): {[1 0],[0 2],[-1  5],[-2  8],[-3 11],[-4 14],[-5 17],[-6 20],[-7 24],[-8 27]}	(3,2): {[0 1],[-1  4],[-2  7],[-3 10],[-4 13],[-5 16],[-6 19],[-7 22],[-8 26],[-9 30]}	(3,3): {}				(3,4): {[0 1],[ 1 -1],[-1  4],[-2  7],[-3 10],[-4 13],[-5 16],[-6 19],[-7 22],[-8 25],[-9 30]}
# (4,0): {[1 1],[0 4],[-1  7],[-2 10],[-3 13],[-4 16],[-5 20]}		(4,1): {[1 0],[0 3],[-1  6],[-2  9],[-3 12],[-4 15],[-5 18],[-6 21],[-7 25]}	(4,2): {[1 0],[0 2],[-1  5],[-2  8],[-3 11],[-4 14],[-5 17],[-6 20],[-7 23],[-8 26]}	(4,3): {[0 1],[ 1 -1],[-1  4],[-2  7],[-3 10],[-4 13],[-5 16],[-6 19],[-7 22],[-8 25],[-9 30]}	(4,4): {}
#
# Away table
#  (0,0): {}				(0,1): {[0 0],[-1  2],[ 1 -2],[ 2 -5],[ 3 -8],[  4 -11],[  5 -14],[  6 -17],[  7 -20],[  8 -24]}	(0,2): {[0 1],[ 1 -1],[ 2 -4],[ 3 -7],[  4 -10],[  5 -13],[  6 -16],[  7 -19],[  8 -23],[  9 -27]}	(0,3): {[1 0],[-1  3],[ 2 -3],[ 3 -6],[ 4 -9],[  5 -12],[  6 -16],[  7 -19],[  8 -22],[  9 -26]}	(0,4): {[1 0],[0 2],[ 2 -3],[ 3 -6],[ 4 -9],[  5 -12],[  6 -16]}
# (1,0): {[0 0],[-1  2],[ 1 -2],[ 2 -5],[ 3 -8],[  4 -11],[  5 -14],[  6 -17],[  7 -20],[  8 -24]}	(1,1): {}				(1,2): {[0 0],[ 1 -2],[ 2 -5],[ 3 -8],[  4 -11],[  5 -14],[  6 -17],[  7 -20],[  8 -24],[  9 -28]}	(1,3): {[0 1],[ 1 -1],[ 2 -4],[ 3 -7],[  4 -10],[  5 -13],[  6 -16],[  7 -19],[  8 -23],[  9 -26]}	(1,4): {[0 1],[ 1 -1],[ 2 -4],[ 3 -7],[  4 -10],[  5 -13],[  6 -16],[  7 -19],[  8 -23]}
# (2,0): {[0 1],[ 1 -1],[ 2 -4],[ 3 -7],[  4 -10],[  5 -13],[  6 -16],[  7 -19],[  8 -23],[  9 -27]}	(2,1): {[0 0],[ 1 -2],[ 2 -5],[ 3 -8],[  4 -11],[  5 -14],[  6 -17],[  7 -20],[  8 -24],[  9 -28]}	(2,2): {}				(2,3): {[0 0],[ 1 -2],[-1  2],[ 2 -5],[ 3 -8],[  4 -11],[  5 -14],[  6 -17],[  7 -20],[  8 -24],[  9 -28]}	(2,4): {[0 1],[ 1 -2],[ 2 -5],[ 3 -8],[  4 -11],[  5 -14],[  6 -17],[  7 -20],[  8 -23]}
# (3,0): {[1 0],[-1  3],[ 2 -3],[ 3 -6],[ 4 -9],[  5 -12],[  6 -16],[  7 -19],[  8 -22],[  9 -26]}	(3,1): {[0 1],[ 1 -1],[ 2 -4],[ 3 -7],[  4 -10],[  5 -13],[  6 -16],[  7 -19],[  8 -23],[  9 -26]}	(3,2): {[0 0],[ 1 -2],[-1  2],[ 2 -5],[ 3 -8],[  4 -11],[  5 -14],[  6 -17],[  7 -20],[  8 -24],[  9 -28]}	(3,3): {}				(3,4): {[0 0],[ 1 -3],[ 2 -6],[ 3 -9],[  4 -12],[  5 -15],[  6 -18],[  7 -21],[  8 -24],[  9 -29]}
# (4,0): {[1 0],[0 2],[ 2 -3],[ 3 -6],[ 4 -9],[  5 -12],[  6 -16]}		(4,1): {[0 1],[ 1 -1],[ 2 -4],[ 3 -7],[  4 -10],[  5 -13],[  6 -16],[  7 -19],[  8 -23]}	(4,2): {[0 1],[ 1 -2],[ 2 -5],[ 3 -8],[  4 -11],[  5 -14],[  6 -17],[  7 -20],[  8 -23]}	(4,3): {[0 0],[ 1 -3],[ 2 -6],[ 3 -9],[  4 -12],[  5 -15],[  6 -18],[  7 -21],[  8 -24],[  9 -29]}	(4,4): {}
#
# -------iter  4  ends-----
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-f09f817e3cdf> in <module>()
#       5       [ 0, 1, 1, 2, 2 ] ]
#       6 R = Rob.Robinson(G,  k = 2)
# ----> 7 R.find_embedding()
#
# ~/Desktop/Dalhousie/Grad/Master's2/Py_Robinson/Robinson.py in find_embedding(self)
#      23             L_alpha = self.L[self.alpha]
#      24
# ---> 25             U_alpha_temp = U_alpha + U_alpha
#      26             L_alpha_temp = L_alpha + L_alpha
#      27
#
# ~/Desktop/Dalhousie/Grad/Master's2/Py_Robinson/Table.py in __add__(self, otherT)
#     102         # T shall be a 2-D array of
#     103         # T = [[BoundsType() for _ in range(n)] for _ in range(n)]
# --> 104         retT = Table(toCpy=self)
#     105         for i in range(self.n):
#     106             for j in range(i+1, self.n):
#
# ~/Desktop/Dalhousie/Grad/Master's2/Py_Robinson/Table.py in __init__(self, n, withArray, toCpy)
#      38                 for j in range(c_n):
#      39                     entry = toCpy.getAt(i, j)
# ---> 40                     self.table[i][j] = entry.cpy(type(entry))
#      41                     self.table[j][i] = self.table[i][j]
#      42             return
#
# ~/Desktop/Dalhousie/Grad/Master's2/Py_Robinson/Bounds.py in cpy(self, BoundsType)
#      22         ret = BoundsType()
#      23         for e in self.bounds:
# ---> 24             ret.union(e.cpy())
#      25         return ret
#      26
#
# ~/Desktop/Dalhousie/Grad/Master's2/Py_Robinson/UpperBounds.py in union(self, elt)
#      18         toAdd = True
#      19         # put index of e's\in bounds s.t. elt < e in a removing list to remove
# ---> 20         for i in range(len(bounds)):
#      21             if elt <= bounds[i]:
#      22                 removeIndex.append(i)
#
# KeyboardInterrupt:

# %%
L1 = R.L_at(0)
U1 = R.U_at(0)
print(R.L_at(0))
#print(R.L_at(0).TypeTable())
print(R.U_at(0))
#print(R.U_at(0).TypeTable())
# Out:
# (0,0): {}	(0,1): {[0 0]}	(0,2): {[0 1]}	(0,3): {[1 0]}	(0,4): {[1 0]}
# (1,0): {[0 0]}	(1,1): {}	(1,2): {[0 0]}	(1,3): {[0 1]}	(1,4): {[0 1]}
# (2,0): {[0 1]}	(2,1): {[0 0]}	(2,2): {}	(2,3): {[0 0]}	(2,4): {[0 1]}
# (3,0): {[1 0]}	(3,1): {[0 1]}	(3,2): {[0 0]}	(3,3): {}	(3,4): {[0 0]}
# (4,0): {[1 0]}	(4,1): {[0 1]}	(4,2): {[0 1]}	(4,3): {[0 0]}	(4,4): {}
#
# (0,0): {}	(0,1): {[0 1]}	(0,2): {[1 0]}	(0,3): {}	(0,4): {}
# (1,0): {[0 1]}	(1,1): {}	(1,2): {[0 1]}	(1,3): {[1 0]}	(1,4): {[1 0]}
# (2,0): {[1 0]}	(2,1): {[0 1]}	(2,2): {}	(2,3): {[0 1]}	(2,4): {[1 0]}
# (3,0): {}	(3,1): {[1 0]}	(3,2): {[0 1]}	(3,3): {}	(3,4): {[0 1]}
# (4,0): {}	(4,1): {[1 0]}	(4,2): {[1 0]}	(4,3): {[0 1]}	(4,4): {}

# %%
L1_5 = L1 + L1
U1_5 = U1 + U1
print("L1+L1:\n",L1_5, "\nU1+U1:\n", U1_5)
# Out:
# L1+L1:
#  (0,0): {}	(0,1): {[0 0]}	(0,2): {[0 1]}	(0,3): {[1 0]}	(0,4): {[1 0],[0 2]}
# (1,0): {[0 0]}	(1,1): {}	(1,2): {[0 0]}	(1,3): {[0 1]}	(1,4): {[0 1]}
# (2,0): {[0 1]}	(2,1): {[0 0]}	(2,2): {}	(2,3): {[0 0]}	(2,4): {[0 1]}
# (3,0): {[1 0]}	(3,1): {[0 1]}	(3,2): {[0 0]}	(3,3): {}	(3,4): {[0 0]}
# (4,0): {[1 0],[0 2]}	(4,1): {[0 1]}	(4,2): {[0 1]}	(4,3): {[0 0]}	(4,4): {}
#
# U1+U1:
#  (0,0): {}	(0,1): {[0 1]}	(0,2): {[1 0],[0 2]}	(0,3): {[1 1]}	(0,4): {[1 1]}
# (1,0): {[0 1]}	(1,1): {}	(1,2): {[0 1]}	(1,3): {[1 0],[0 2]}	(1,4): {[1 0]}
# (2,0): {[1 0],[0 2]}	(2,1): {[0 1]}	(2,2): {}	(2,3): {[0 1]}	(2,4): {[1 0],[0 2]}
# (3,0): {[1 1]}	(3,1): {[1 0],[0 2]}	(3,2): {[0 1]}	(3,3): {}	(3,4): {[0 1]}
# (4,0): {[1 1]}	(4,1): {[1 0]}	(4,2): {[1 0],[0 2]}	(4,3): {[0 1]}	(4,4): {}

# %%
L2 = L1_5 - U1
U2 = U1_5 - L1
print(L2,"\n", U2)
# Out:
# (0,0): {}	(0,1): {[0 1]}	(0,2): {[0 1],[ 1 -1]}	(0,3): {[1 0]}	(0,4): {[1 0],[0 2]}	(0,5): {[1 1]}
# (1,0): {[0 1]}	(1,1): {}	(1,2): {[0 0],[-1  2]}	(1,3): {[0 1],[ 1 -1]}	(1,4): {[0 1],[ 1 -1]}	(1,5): {[0 2],[1 0]}
# (2,0): {[0 1],[ 1 -1]}	(2,1): {[0 0],[-1  2]}	(2,2): {}	(2,3): {[0 0]}	(2,4): {[0 1]}	(2,5): {[0 1]}
# (3,0): {[1 0]}	(3,1): {[0 1],[ 1 -1]}	(3,2): {[0 0]}	(3,3): {}	(3,4): {[0 0]}	(3,5): {[0 1]}
# (4,0): {[1 0],[0 2]}	(4,1): {[0 1],[ 1 -1]}	(4,2): {[0 1]}	(4,3): {[0 0]}	(4,4): {}	(4,5): {[0 0],[-1  2]}
# (5,0): {[1 1]}	(5,1): {[0 2],[1 0]}	(5,2): {[0 1]}	(5,3): {[0 1]}	(5,4): {[0 0],[-1  2]}	(5,5): {}
#
#  (0,0): {}	(0,1): {[0 1]}	(0,2): {[1 0],[0 2]}	(0,3): {[1 0]}	(0,4): {[1 1]}	(0,5): {[1 1]}
# (1,0): {[0 1]}	(1,1): {}	(1,2): {[0 1],[ 1 -1]}	(1,3): {[0 2],[ 1 -1]}	(1,4): {[1 0]}	(1,5): {[1 0]}
# (2,0): {[1 0],[0 2]}	(2,1): {[0 1],[ 1 -1]}	(2,2): {}	(2,3): {[0 1],[ 1 -1]}	(2,4): {[1 0],[0 2]}	(2,5): {[1 0]}
# (3,0): {[1 0]}	(3,1): {[0 2],[ 1 -1]}	(3,2): {[0 1],[ 1 -1]}	(3,3): {}	(3,4): {[0 1],[ 1 -1]}	(3,5): {[0 1],[ 1 -1]}
# (4,0): {[1 1]}	(4,1): {[1 0]}	(4,2): {[1 0],[0 2]}	(4,3): {[0 1],[ 1 -1]}	(4,4): {}	(4,5): {[0 1],[ 1 -1]}
# (5,0): {[1 1]}	(5,1): {[1 0]}	(5,2): {[1 0]}	(5,3): {[0 1],[ 1 -1]}	(5,4): {[0 1],[ 1 -1]}	(5,5): {}

# %%
a
